# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_2014 = pd.read_csv('./new_data/2014_US_exchange.csv', index_col=0)
df_2015 = pd.read_csv('./new_data/2015_US_exchange.csv', index_col=0)
df_2016 = pd.read_csv('./new_data/2016_US_exchange.csv', index_col=0)
df_2017 = pd.read_csv('./new_data/2017_US_exchange.csv', index_col=0)
df_2018 = pd.read_csv('./new_data/2018_US_exchange.csv', index_col=0)

# %%
df_2014.head(5)
# Out:
#   Symbol       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0     PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1   VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2     KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3    RAD  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4    GIS  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
#
#    R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# 0  0.000000e+00  2.146100e+10        2.146100e+10      1.391000e+10
# 1  1.083303e+08  3.441414e+08        7.939267e+08      1.345959e+08
# 2  0.000000e+00  1.519600e+10        1.751200e+10      2.725000e+09
# 3  0.000000e+00  6.561162e+09        6.586482e+09      7.372520e+08
# 4  0.000000e+00  3.474300e+09        3.412400e+09      2.957400e+09
#
#    Interest Expense  ...  Receivables growth  Inventory Growth  Asset Growth  \
# ...

# %%
df_2014.tail(5)
# Out:
#      Symbol      Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 3802   TRNS  118508000.0          0.0553       88718000.0    29790000.0
# 3803   TSRI   49529867.0          0.1028       41251638.0     8278229.0
# 3804   TZOO  153240000.0         -0.1019       19174000.0   134066000.0
# 3805  USATP   42000000.0             NaN       27000000.0    15000000.0
# 3806   WSTG  340758000.0          0.1344      315948000.0    24810000.0
#
#       R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# 3802           0.0    23085000.0          23085000.0         6705000.0
# 3803           0.0     8253061.0           8253061.0           25168.0
# 3804    11326000.0   112513000.0         116256000.0        17810000.0
# 3805           NaN    14000000.0          15000000.0               0.0
# 3806           0.0    16513000.0          16513000.0         8297000.0
#
#       Interest Expense  ...  Receivables growth  Inventory Growth  \
# ...

# %%
print("Shape of year 2014: {}".format(df_2014.shape))
print("Shape of year 2015: {}".format(df_2015.shape))
print("Shape of year 2016: {}".format(df_2016.shape))
print("Shape of year 2017: {}".format(df_2017.shape))
print("Shape of year 2018: {}".format(df_2018.shape))
# Out:
# Shape of year 2014: (3162, 225)
# Shape of year 2015: (3268, 225)
# Shape of year 2016: (3657, 225)
# Shape of year 2017: (3741, 225)
# Shape of year 2018: (3288, 225)

# %%
df_2014.columns
# Out:
# Index(['Symbol', 'Revenue', 'Revenue Growth', 'Cost of Revenue',
#        'Gross Profit', 'R&D Expenses', 'SG&A Expense', 'Operating Expenses',
#        'Operating Income', 'Interest Expense',
#        ...
#        'Receivables growth', 'Inventory Growth', 'Asset Growth',
#        'Book Value per Share Growth', 'Debt Growth', 'R&D Expense Growth',
#        'SG&A Expenses Growth', 'Sector', '2015 PRICE VAR [%]', 'Class'],
#       dtype='object', length=225)

# %%
df_2014.rename(columns={"2015 PRICE VAR [%]": "PRICE_VAR"},inplace=True)
df_2015.rename(columns={"2016 PRICE VAR [%]": "PRICE_VAR"},inplace=True)
df_2016.rename(columns={"2017 PRICE VAR [%]": "PRICE_VAR"},inplace=True)
df_2017.rename(columns={"2018 PRICE VAR [%]": "PRICE_VAR"},inplace=True)
df_2018.rename(columns={"2019 PRICE VAR [%]": "PRICE_VAR"},inplace=True)

# %%
# Rename the train, validation and test sets
train = pd.concat([df_2014, df_2015, df_2016])
val = df_2017
test = df_2018
print(train.shape)
# Out:
# (10087, 225)

# %%
train.head(5)
# Out:
#   Symbol       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0     PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1   VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2     KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3    RAD  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4    GIS  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
#
#    R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# 0  0.000000e+00  2.146100e+10        2.146100e+10      1.391000e+10
# 1  1.083303e+08  3.441414e+08        7.939267e+08      1.345959e+08
# 2  0.000000e+00  1.519600e+10        1.751200e+10      2.725000e+09
# 3  0.000000e+00  6.561162e+09        6.586482e+09      7.372520e+08
# 4  0.000000e+00  3.474300e+09        3.412400e+09      2.957400e+09
#
#    Interest Expense  ...  Receivables growth  Inventory Growth  Asset Growth  \
# ...

# %%
train.drop(['PRICE_VAR'], axis=1, inplace=True)
train.head(5)
# Out:
#   Symbol       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0     PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1   VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2     KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3    RAD  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4    GIS  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
#
#    R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# 0  0.000000e+00  2.146100e+10        2.146100e+10      1.391000e+10
# 1  1.083303e+08  3.441414e+08        7.939267e+08      1.345959e+08
# 2  0.000000e+00  1.519600e+10        1.751200e+10      2.725000e+09
# 3  0.000000e+00  6.561162e+09        6.586482e+09      7.372520e+08
# 4  0.000000e+00  3.474300e+09        3.412400e+09      2.957400e+09
#
#    Interest Expense  ...  3Y Dividend per Share Growth (per Share)  \
# ...

# %%
# Getting the columns with'Growth'
df_growth = train.filter(regex='rowth')
df_growth.head(5)
# Out:
#    Revenue Growth  priceEarningsToGrowthRatio  Gross Profit Growth  \
# 0         -0.0713                   15.557842              -0.1185
# 1          1.1737                    2.631793               1.2489
# 2          0.0182                    0.000000               0.0173
# 3          0.0053                    0.000000               0.0007
# 4          0.0076                   15.254287              -0.0084
#
#    EBIT Growth  Operating Income Growth  Net Income Growth  EPS Growth  \
# 0      -0.0001                   0.0067             0.0293      0.0371
# 1       1.6142                   1.9463             1.5649      1.4625
# 2      -0.0145                  -0.0141             0.0147      0.0576
# 3       0.2904                   0.1113             1.0043      0.9167
# 4       0.0332                   0.0370            -0.0166      0.0140
#
#    EPS Diluted Growth  Weighted Average Shares Growth  \
# 0              0.0389                         -0.0127
# ...

# %%
# Getting the columns with 'Profit'
df_profit = train.filter(regex='ofit')
df_profit.head(5)
# Out:
#    Gross Profit  Profit Margin  Net Profit Margin  grossProfitMargin  \
# 0  3.537100e+10         0.1560             0.1565           0.475410
# 1  9.285226e+08         0.0058             0.0364           0.248657
# 2  2.023700e+10         0.0150             0.0154           0.205713
# 3  7.323734e+09         0.0080             0.0098           0.286908
# 4  6.369800e+09         0.1020             0.1019           0.355664
#
#    operatingProfitMargin  pretaxProfitMargin  netProfitMargin  \
# 0                    1.0            0.186960         0.156490
# 1                    1.0            0.036045         0.036373
# 2                    1.0            0.027700         0.015441
# 3                    1.0            0.028882         0.009771
# 4                    1.0            0.165129         0.101867
#
#    Gross Profit Growth
# 0              -0.1185
# 1               1.2489
# 2               0.0173
# 3               0.0007
# 4              -0.0084

# %%
# Getting the columns with 'Expense'
df_expense = train.filter(regex='xpense')
df_expense.head(5)
# Out:
#    R&D Expenses  SG&A Expense  Operating Expenses  Interest Expense  \
# 0  0.000000e+00  2.146100e+10        2.146100e+10      7.090000e+08
# 1  1.083303e+08  3.441414e+08        7.939267e+08      1.214869e+07
# 2  0.000000e+00  1.519600e+10        1.751200e+10      4.430000e+08
# 3  0.000000e+00  6.561162e+09        6.586482e+09      4.245910e+08
# 4  0.000000e+00  3.474300e+09        3.412400e+09      3.024000e+08
#
#    Income Tax Expense  R&D Expense Growth  SG&A Expenses Growth
# 0        2.851000e+09              0.0000               -0.1746
# 1        3.955957e+07              1.6484                1.7313
# 2        7.510000e+08              0.0000                0.0234
# 3        8.040000e+05              0.0000               -0.0060
# 4        8.833000e+08              0.0000               -0.0220

# %%
# Getting the columns with 'Ratio'
df_ratio = train.filter(regex='Ratio|ratio')
df_ratio.head(5)
# Out:
#    priceBookValueRatio  priceToBookRatio  priceToSalesRatio  \
# 0               3.0391            0.0000             2.8583
# 1                  NaN               NaN             0.0443
# 2               3.3579            7.0982             0.1858
# 3               0.0000            0.0000             0.2491
# 4               5.1004            0.0000             1.8610
#
#    priceEarningsRatio  priceToFreeCashFlowsRatio  \
# 0             18.7566                    21.0348
# 1             81.5526                     1.3589
# 2             12.0340                    14.6302
# 3             28.6087                    17.2736
# 4             18.7034                    17.6902
#
#    priceToOperatingCashFlowsRatio  priceCashFlowRatio  \
# 0                         15.2358           12.977501
# 1                             NaN            0.678615
# 2                          5.1147            0.000000
# 3                          9.0589            0.000000
# ...

# %%
# Getting the columns with 'turnover'
df_turnover = train.filter(regex='Turnover|turnover')
df_turnover.head(5)
# Out:
#    payablesTurnover  inventoryTurnover  fixedAssetTurnover  assetTurnover  \
# 0            1.5648            10.8869            3.335769       0.515721
# 1               NaN                NaN           12.100383       1.364477
# 2            4.9593            18.2227            5.823418       3.359687
# 3            4.9289             8.3030           13.041452       3.675578
# 4            2.8234            11.5363            4.543393       0.773777
#
#    Receivables Turnover  Payables Turnover  Inventory Turnover
# 0               11.5404             1.5648             10.8869
# 1                   NaN                NaN                 NaN
# 2               90.7937             4.9593             18.2227
# 3               27.1769             4.9289              8.3030
# 4               12.2250             2.8234             11.5363

# %%
train_features = train.iloc[:, :-1]
train_features
# Out:
#      Symbol       Revenue  Revenue Growth  Cost of Revenue  Gross Profit  \
# 0        PG  7.440100e+10         -0.0713     3.903000e+10  3.537100e+10
# 1      VIPS  3.734148e+09          1.1737     2.805625e+09  9.285226e+08
# 2        KR  9.837500e+10          0.0182     7.813800e+10  2.023700e+10
# 3       RAD  2.552641e+10          0.0053     1.820268e+10  7.323734e+09
# 4       GIS  1.790960e+10          0.0076     1.153980e+10  6.369800e+09
# ...     ...           ...             ...              ...           ...
# 4791   TRNS  1.221660e+08         -0.0118     9.304700e+07  2.911900e+07
# 4792   TSRI  6.099828e+07          0.0626     5.103888e+07  9.959402e+06
# 4793   TZOO  1.142630e+08         -0.0782     1.385500e+07  1.004080e+08
# 4794  USATP  7.700000e+07             NaN     5.500000e+07  2.200000e+07
# 4795   WSTG  1.646090e+08         -0.5692     1.372780e+08  2.733100e+07
#
#       R&D Expenses  SG&A Expense  Operating Expenses  Operating Income  \
# ...

# %%
train_label = train.iloc[:, -1]
train_label
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 4791    1
# 4792    1
# 4793    0
# 4794    1
# 4795    0
# Name: Class, Length: 10087, dtype: int64

# %%
val_features = val.iloc[:, :-1]
val_label = val.iloc[:, -1]
test_features = test.iloc[:, :-1]
test_label = test.iloc[:, -1]

# %%
fig = sns.countplot(train_label)
plt.show()
# Out:
# /Users/ngo00054/opt/anaconda3/envs/DataMining/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Start with only a few features: 10
features = ['Revenue', 'Net Profit Margin', 'grossProfitMargin', 'debtEquityRatio', 'Total current assets', 'Debt to Assets', 'Tangible Asset Value', 'Total current liabilities', 'returnOnEquity', 'Operating Income Growth']
X_train_10 = train_features[features]
X_train_10.head(5)
# Out:
#         Revenue  Net Profit Margin  grossProfitMargin  debtEquityRatio  \
# 0  7.440100e+10             0.1565           0.475410           0.5061
# 1  3.734148e+09             0.0364           0.248657           1.5093
# 2  9.837500e+10             0.0154           0.205713           2.1007
# 3  2.552641e+10             0.0098           0.286908          -2.7237
# 4  1.790960e+10             0.1019           0.355664           1.3445
#
#    Total current assets  Debt to Assets  Tangible Asset Value  \
# 0          3.161700e+10          0.2455          5.971900e+10
# 1          2.134397e+09          0.2274          2.546029e+09
# 2          8.830000e+09          0.3863          2.644400e+10
# 3          4.285125e+09          0.8290          6.513644e+09
# 4          4.393500e+09          0.3796          9.480900e+09
#
#    Total current liabilities  returnOnEquity  Operating Income Growth
# 0               3.372600e+10          0.1664                   0.0067
# ...

# %%
plt.figure(figsize=(12,10))
cor = X_train_10.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
X_train_10.describe()
# Out:
#             Revenue  Net Profit Margin  grossProfitMargin  debtEquityRatio  \
# count  9.642000e+03        9458.000000        9114.000000      9203.000000
# mean   6.330522e+09          -6.309841           0.504884         0.622572
# std    3.953524e+10         146.406714           1.049147        36.739681
# min   -6.276160e+08       -8964.916400         -74.319113     -2586.435900
# 25%    1.070160e+08          -0.000500           0.280398         0.053300
# 50%    6.274103e+08           0.055600           0.473675         0.491400
# 75%    2.960280e+09           0.146675           0.803626         1.118800
# max    1.886894e+12          40.807500           2.659945      2131.512800
#
#        Total current assets  Debt to Assets  Tangible Asset Value  \
# count          8.708000e+03     9203.000000          9.229000e+03
# mean           6.241703e+09        0.251691          2.007569e+10
# std            5.093581e+10        0.293355          1.260095e+11
# ...

# %%
X_train_10.replace([np.inf, -np.inf], np.nan)
X_train_10.fillna(0, inplace=True)
# Out:
# /Users/ngo00054/opt/anaconda3/envs/DataMining/lib/python3.8/site-packages/pandas/core/frame.py:4462: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
X_train_10.isnull().sum().sum()
np.where(np.isnan(X_train_10))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
X_val_10 = val_features[features]
X_test_10 = test_features[features]
X_val_10.replace([np.inf, -np.inf], np.nan)
X_val_10.fillna(0, inplace=True)
X_test_10.replace([np.inf, -np.inf], np.nan)
X_test_10.fillna(0, inplace=True)

# %%
# Import classifiers
# Start with Random Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# %%
# Start with the default parameters. Will change max_depth later
rf_model = RandomForestClassifier(random_state=0)
rf_model.fit(X_train_10, train_label)

# Prediction
train_pred = rf_model.predict(X_train_10)
train_acc = accuracy_score(train_label, train_pred)
train_f1 = f1_score(train_label, train_pred)
print("Train Accuracy: {:.4f}".format(train_acc))
print("Train F1 Score: {:.4f}".format(train_f1))

val_pred = rf_model.predict(X_val_10)
val_acc = accuracy_score(val_label, val_pred)
val_f1 = f1_score(val_label, val_pred)
print("Val Accuracy: {:.4f}".format(val_acc))
print("Val F1 Score: {:.4f}".format(val_f1))

print("Val Confusion Matrix: ")
tn, fp, fn, tp = confusion_matrix(val_label, val_pred).ravel()
print(confusion_matrix(val_label, val_pred))
print("Val False Discovery Rate: {:.4f}".format(fp/(fp+tn)))

test_pred = rf_model.predict(X_test_10)
test_acc = accuracy_score(test_label, test_pred)
test_f1 = f1_score(test_label, test_pred)
print("Test Accuracy: {:.4f}".format(test_acc))
print("Test F1 Score: {:.4f}".format(test_f1))

print("Test Confusion Matrix: ")
tn, fp, fn, tp = confusion_matrix(test_label, test_pred).ravel()
print(confusion_matrix(test_label, test_pred))
print("Test False Discovery Rate: {:.4f}".format(fp/(fp+tn)))
# Pretty bad False Discovery Rate. Skewed dataset
# Out:
# Train Accuracy: 0.9946
# Train F1 Score: 0.9957
# Val Accuracy: 0.3571
# Val F1 Score: 0.4001
# Val Confusion Matrix:
# [[ 534 2162]
#  [ 243  802]]
# Val False Discovery Rate: 0.8019
# Test Accuracy: 0.7007
# Test F1 Score: 0.8026
# Test Confusion Matrix:
# [[ 303  589]
#  [ 395 2001]]
# Test False Discovery Rate: 0.6603

# %%
# Start with the default parameters. Will change max_depth later
rf_model = RandomForestClassifier(max_depth=4, random_state=0)
rf_model.fit(X_train_10, train_label)

# Prediction
train_pred = rf_model.predict(X_train_10)
train_acc = accuracy_score(train_label, train_pred)
train_f1 = f1_score(train_label, train_pred)
print("Train Accuracy: {:.4f}".format(train_acc))
print("Train F1 Score: {:.4f}".format(train_f1))

val_pred = rf_model.predict(X_val_10)
val_acc = accuracy_score(val_label, val_pred)
val_f1 = f1_score(val_label, val_pred)
print("Val Accuracy: {:.4f}".format(val_acc))
print("Val F1 Score: {:.4f}".format(val_f1))

print("Val Confusion Matrix: ")
tn, fp, fn, tp = confusion_matrix(val_label, val_pred).ravel()
print(confusion_matrix(val_label, val_pred))
print("Val False Discovery Rate: {:.4f}".format(fp/(fp+tn)))

test_pred = rf_model.predict(X_test_10)
test_acc = accuracy_score(test_label, test_pred)
test_f1 = f1_score(test_label, test_pred)
print("Test Accuracy: {:.4f}".format(test_acc))
print("Test F1 Score: {:.4f}".format(test_f1))

print("Test Confusion Matrix: ")
tn, fp, fn, tp = confusion_matrix(test_label, test_pred).ravel()
print(confusion_matrix(test_label, test_pred))
print("Test False Discovery Rate: {:.4f}".format(fp/(fp+tn)))
# Out:
# Train Accuracy: 0.6531
# Train F1 Score: 0.7705
# Val Accuracy: 0.3229
# Val F1 Score: 0.4314
# Val Confusion Matrix:
# [[ 247 2449]
#  [  84  961]]
# Val False Discovery Rate: 0.9084
# Test Accuracy: 0.7372
# Test F1 Score: 0.8386
# Test Confusion Matrix:
# [[ 179  713]
#  [ 151 2245]]
# Test False Discovery Rate: 0.7993

# %%
# Feature Selection: Using select KBest and ANOVA f-1 score
from sklearn.feature_selection import SelectKBest, f_classif

# %%
train_features.shape
# Out:
# (10087, 223)

# %%
X_train_clean = train_features.drop(['Symbol', 'Sector'], axis=1)
X_train_clean.replace([np.inf, -np.inf], np.nan)
X_train_clean.fillna(0, inplace=True)

# %%
train_KBest = SelectKBest(f_classif, k=10).fit_transform(X_train_clean, train_label)
train_KBest.shape
# Out:
# (10087, 10)
