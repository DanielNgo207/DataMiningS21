# %%
import pandas as pd
import numpy as np
df_2014 = pd.read_csv('./new_data/2014_US_exchange.csv')
df_2015 = pd.read_csv('./new_data/2015_US_exchange.csv')
df_2016 = pd.read_csv('./new_data/2016_US_exchange.csv')
df_2017 = pd.read_csv('./new_data/2017_US_exchange.csv')
df_2018 = pd.read_csv('./new_data/2018_US_exchange.csv')

# %%
df_2014.head()
# Out:
#    Unnamed: 0 Symbol       Revenue  Revenue Growth  Cost of Revenue  \
# 0           0     PG  7.440100e+10         -0.0713     3.903000e+10
# 1           1   VIPS  3.734148e+09          1.1737     2.805625e+09
# 2           2     KR  9.837500e+10          0.0182     7.813800e+10
# 3           3    RAD  2.552641e+10          0.0053     1.820268e+10
# 4           4    GIS  1.790960e+10          0.0076     1.153980e+10
#
#    Gross Profit  R&D Expenses  SG&A Expense  Operating Expenses  \
# 0  3.537100e+10  0.000000e+00  2.146100e+10        2.146100e+10
# 1  9.285226e+08  1.083303e+08  3.441414e+08        7.939267e+08
# 2  2.023700e+10  0.000000e+00  1.519600e+10        1.751200e+10
# 3  7.323734e+09  0.000000e+00  6.561162e+09        6.586482e+09
# 4  6.369800e+09  0.000000e+00  3.474300e+09        3.412400e+09
#
#    Operating Income  ...  Receivables growth  Inventory Growth  Asset Growth  \
# 0      1.391000e+10  ...             -0.0187           -0.0217        0.0359
# ...

# %%
y = df_2014['Class']
symbol = df_2014['Symbol']
sector = df_2014['Sector']
df_2014.drop(['Class', 'Symbol', 'Sector'], axis=1, inplace=True)
df_2014 = df_2014.fillna(0)

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

X_train, X_test, y_train, y_test = train_test_split(df_2014.values, 
                                                    y,test_size=0.3, 
                                                    random_state=1)

knn = KNeighborsClassifier(n_neighbors=43)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=43)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

knn_pred = knn.predict(X_test_scaled)
print (f" Accuracy for k-nn is {accuracy_score(y_test, knn_pred)}")
# Out:
#  Accuracy for k-nn is 0.7418335089567967
